# %%
from youtube_transcript_api import YouTubeTranscriptApi
transcript_dict = YouTubeTranscriptApi.get_transcript("-IlG32Pb43g")
transcript_dict
# Out:
# [{'text': 'Have you ever tried petting a cat, but every\xa0\ntime you come closer, the cat runs away and\xa0\xa0',
#   'start': 0.48,
#   'duration': 4.8},
#  {'text': 'keeps watching you from a distance? Then,\xa0\nyou walk towards the cat in a second attempt,\xa0\xa0',
#   'start': 5.28,
#   'duration': 5.04},
#  {'text': 'but it runs away again. When you approach the cat\xa0\na third time, it flees and disappears. However,\xa0\xa0',
#   'start': 10.32,
#   'duration': 6.8},
#  {'text': 'a few hours later, when you’ve focused your\xa0\nattention on something else, the cat appears,\xa0\xa0',
#   'start': 17.12,
#   'duration': 4.96},
#  {'text': 'walks toward you, and jumps onto your lap.\nA phenomenon we often experience is that when\xa0\xa0',
#   'start': 22.08,
#   'duration': 6.56},
#  {'text': 'we chase something or someone, it moves away from\xa0\nus. But when we leave it alone, it comes to us.\xa0\xa0',
#   'start': 28.64,
#   'duration': 6.0},
# ...

# %%
transcript_text = ""
for transcript in transcript_dict:
    transcript_text += transcript["text"]
transcript_text
# Out:
# 'Have you ever tried petting a cat, but every\xa0\ntime you come closer, the cat runs away and\xa0\xa0keeps watching you from a distance? Then,\xa0\nyou walk towards the cat in a second attempt,\xa0\xa0but it runs away again. When you approach the cat\xa0\na third time, it flees and disappears. However,\xa0\xa0a few hours later, when you’ve focused your\xa0\nattention on something else, the cat appears,\xa0\xa0walks toward you, and jumps onto your lap.\nA phenomenon we often experience is that when\xa0\xa0we chase something or someone, it moves away from\xa0\nus. But when we leave it alone, it comes to us.\xa0\xa0This mechanism can be hard to reconcile with the\xa0\nidea that ‘effort’ is the key to success. Even\xa0\xa0though it’s true that achieving goals often\xa0\nrequires work, there’s also another side to\xa0\xa0the story. The law of reversed effort shows us\xa0\nthat, in many situations, putting in work only\xa0\xa0removes us further from the desired outcome.\xa0\nAnd that the 
# ...

# %%
str(["Hello"])
# Out:
# "['Hello']"
